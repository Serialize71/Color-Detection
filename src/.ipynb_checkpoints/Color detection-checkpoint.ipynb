# %%
import os    
import numpy as py
import matplotlib.pyplot as plt
import cv2
import time
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
cap = cv2.VideoCapture(0)
width = str(int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)))
height = str(int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
strWH = width , height
while True:
    ret , frame = cap.read()
    cv2.rectangle(frame , (100 , 160)  ,  (150 , 210) , (0 , 0 , 255) , 3)
    rot = frame[160:210 , 100:150] #rows > y axis , columns > x axis
    changed_rot = cv2.cvtColor(rot , cv2.COLOR_BGR2HSV)
    frame[160:210 , 100:150] = changed_rot
    cv2.putText(frame ,  str(strWH) , (1,40) , cv2.FONT_HERSHEY_COMPLEX ,  1 , (255 , 0  , 0) , 2 , cv2.LINE_AA)                          
    cv2.imshow("frame" , frame)
    print(changed_rot)
    time.sleep(1)
    if cv2.waitKey(15) == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [[[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  ...
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [111  14 188]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]]
# [[[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
#   [  0 255 255]
#   ...
#   [  0 255 255]
#   [  0 255 255]
#   [  0 255 255]]
#
#  [[  0 255 255]
#   [  0 255 255]
# ...
